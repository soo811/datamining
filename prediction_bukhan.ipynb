# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/bukhan.csv')
data2 = pd.read_csv('./data/autumn_day.csv')

# %%
data
# Out:
#     year  mtemp_8  mtemp_9  rain_8  rain_9   sun_8   sun_9
# 0   2010     26.5     21.8   598.7   671.5  365.07  373.65
# 1   2011     25.8     21.8   166.8    25.6  378.91  449.39
# 2   2012     27.1     21.0   464.9   212.0  362.84  356.28
# 3   2013     27.7     21.8   148.6   138.5  420.57  368.82
# 4   2014     25.2     22.1   172.8    88.1  352.98  388.56
# 5   2015     26.3     22.4    72.9    26.0  436.33  458.73
# 6   2016     28.0     23.1    67.1    33.0  468.05  370.92
# 7   2017     25.9     22.1   297.0    35.0  411.09  445.23
# 8   2018     28.8     21.5   202.6    68.5  517.16  470.96
# 9   2019     27.2     22.6   190.5   139.8  486.24  386.78
# 10  2020     26.5     21.4   675.7   181.5  325.97  452.05
# 11  2021     25.9     22.6   211.2   131.0  428.88  474.13
# 12  2022     25.7     22.4   564.8   201.5  402.81  496.22

# %%
data2
# Out:
#     Unnamed: 0  Bukhan  Chiak  Gyeryong  Jiri  Naejang
# 0         2010     291    282       291   283      298
# 1         2011     287    280       290   285      298
# 2         2012     289    282       290   283      292
# 3         2013     292    287       289   280      295
# 4         2014     286    275       286   281      295
# 5         2015     287    279       286   281      292
# 6         2016     291    278       288   285      296
# 7         2017     287    278       286   284      293
# 8         2018     285    281       284   285      294
# 9         2019     284    280       290   297      297
# 10        2020     290    282       289   289      293
# 11        2021     293    281       298   299      302
# 12        2022     291    280       291   291      298

# %%
data3 = pd.read_csv('./data/2023_mt.csv')

# %%
data3
# Out:
#    mtemp_8  mtemp_9  rain_8  rain_9   sun_8   sun_9       lati        long  \
# 0     27.2     23.7   298.1   134.5  469.76  425.79  37.658653  126.977992
# 1     26.7     22.7   233.0   158.6  501.57  438.40  37.365125  128.055647
# 2     27.0     22.8   326.9   310.2  542.41  443.12  35.528419  127.008797
# 3     26.9     23.0   406.1   117.6  568.06  446.45  35.336911  127.730625
# 4     27.0     22.7   304.5   123.0  599.42  443.90  35.478342  126.889014
#
#       elv  date
# 0   835.6   290
# 1  1282.0   283
# 2   402.5   292
# 3  1915.4   293
# 4   763.5   300

# %%
test_x = data3.iloc[0, :6]
test_x = np.array(test_x).reshape(1,6)
test_y = data3.iloc[0, -1]

# %%
train_x = data.iloc[:, 1:]
train_y = data2.iloc[:, 1]

# %%
# 선형회귀
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(train_x, train_y)
pred = model.predict(test_x)
pred
# Out:
# C:\Users\0811j\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([292.89729775])

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [ 3.25978737  4.34166379 -0.0048097   0.00833886 -0.08157958  0.03630682]
# 124.50958507868992

# %%
print(test_y)
# Out:
# 290

# %%
import joblib
joblib.dump(model, './bukhan.pkl')
# Out:
# ['./bukhan.pkl']

# %%
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras import layers

model = keras.Sequential()
model.add(Dense(12, input_shape=(6, )))
model.add(layers.Activation('relu'))

model.add(layers.Dense(12))
model.add(layers.Activation('relu'))

model.add(Dense(1))
model.add(layers.Activation('linear'))

op = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mse', optimizer=op, metrics=['accuracy'])

# %%
model.fit(train_x, train_y, epochs=10000)
pred = model.predict(test_x)
pred
# Out:
# Train on 13 samples
# Epoch 1/10000
# 13/13 [==============================] - 0s 10ms/sample - loss: 10283.8916 - acc: 0.0000e+00
# Epoch 2/10000
# 13/13 [==============================] - 0s 286us/sample - loss: 9542.5488 - acc: 0.0000e+00
# Epoch 3/10000
# 13/13 [==============================] - 0s 155us/sample - loss: 8853.3516 - acc: 0.0000e+00
# Epoch 4/10000
# 13/13 [==============================] - 0s 77us/sample - loss: 8218.7295 - acc: 0.0000e+00
# Epoch 5/10000
# 13/13 [==============================] - 0s 163us/sample - loss: 7632.9819 - acc: 0.0000e+00
# Epoch 6/10000
# 13/13 [==============================] - 0s 78us/sample - loss: 7095.1396 - acc: 0.0000e+00
# Epoch 7/10000
# 13/13 [==============================] - 0s 292us/sample - loss: 6604.7290 - acc: 0.0000e+00
# Epoch 8/10000
# 13/13 [==============================] - 0s 154us/sample - loss: 6161.0981 - acc: 0.0000e+00
# Epoch 9/10000
# ...
